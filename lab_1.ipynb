# %% [markdown]
# # Lab Assignment 1
# ### MPATE-GE 2598 Fundamentals of Digital Signal Theory Lab

# %% [markdown]
# Your first lab tests your grasp of Python programming fundamentals. Please read the instructions carefully.
#
# As a reminder, you are encouraged to work together and reach out for help if you get stumped.

# %% [markdown]
# ## Markdown

# %% [markdown]
# First, let's practice writing in Markdown. Fill out the information below.

# %% [markdown]
# **Full Name:** Ian Zhu
#
# **Net ID:** yz10616

# %% [markdown]
# ## Conceptual Questions

# %% [markdown]
# (a) What is the fundamental building block of the Python programming language?

# %% [markdown]
# **Answer:** The fundamental building block of Python is the object. In Python, everything (including numbers, strings, functions, lists, and classes) is an object with an identity, a type, and a value.

# %% [markdown]
# (b) Provide an example of an _invalid_ variable name in Python and explain why it is not acceptable.

# %% [markdown]
# **Answer:** x, as it can be anything, but it is not clear to represent anything
# 2nd_album is an invalid variable name. In Python, variable names cannot start with a digit; they must begin with a letter or an underscore (_).

# %% [markdown]
# (c) Explain what a `SyntaxError` is.

# %% [markdown]
# **Answer:** When you did not follow the python grammar requirement. Like did not add : after if condition.
# SyntaxError occurs when Python encounters code that breaks its grammatical rules (such as a missing colon, mismatched parentheses, or misspelled keyword). It is raised during the parsing phase before the code actually executes.

# %% [markdown]
# (d) True or False: When you shut down or restart your Jupyter notebook, the objects you created during your Python session are saved. Explain your answer.

# %% [markdown]
# **Answer:** False, you have to manually save it.

# %% [markdown]
# ## Variables and Data Types

# %% [markdown]
# (a) In the cell below, create the following variables and assign values to them based on information about yourself. Make sure the variables have the data types specified in parentheses.
# * `name` (`str`) - your name
# * `program` (`str`) - your degree program
# * `year` (`int`) - which year of your program you are currently in

# %%
# YOUR CODE HERE
name = "Ian"
program = "Music Technology"
year = 1

# %% [markdown]
# (b) Now, write the code to output (print) the following text using the variables you defined above. The `<>` represent where you should use your variables.
# ```
# Hi! My name is <Richa>. I am in my <4>th year of the <Music Technology PhD> program.
# ```

# %%
# YOUR CODE HERE
print("Hello, my name is " + name + ". I am in my " + str(year) + " year of the " + program + " program.")
# Out:
# Hello, my name is Ian. I am in my 1 year of the Music Technology program.

# %% [markdown]
# (c) Add `0.5` to the variable `year` and save the result to a variable called `next_semester`. Show the data type of this new variable.

# %%
# YOUR CODE HERE
next_semester = year + 0.5
print(next_semester)
type(next_semester)
# Out:
# 1.5
# float

# %% [markdown]
# ## Data Structures

# %% [markdown]
# Below is a list of tuples called `albums`. It contains information about three albums that are on the Billboard 200™ for the week of August 30, 2025. Each tuple represents one album with its data in the following order: title, artist, number of weeks on the chart, and whether it is currently in the top 10. Run the cell below to create this list.

# %%
albums = [("SOS", "SZA", 141, True),
          ("DeBÍ TiRAR MáS FOToS", "Bad Bunny", 33, False),
          ("Rumours", "Fleetwood Mac", 647, False)]

# %% [markdown]
# (a) Using indexing, select the album data for "DeBÍ TiRAR MáS FOToS" and save it to a variable named `benito`.

# %%
# YOUR CODE HERE
benito = albums[1]
print(benito)
# Out:
# ('DeBÍ TiRAR MáS FOToS', 'Bad Bunny', 33, False)

# %% [markdown]
# (b) Let's say that a week goes by and "DeBÍ TiRAR MáS FOToS" is now in the top 10. What happens if you try to update `benito` and replace the `False` with a `True`? Explain why this is the case.

# %% [markdown]
# **Answer:** Trying to directly modify benito[3] = True raises a TypeError. Tuples in Python are immutable, meaning their elements cannot be changed, updated, or reassigned after creation. To update it, you would need to recreate the tuple.

# %% [markdown]
# (c) Using indexing, output how many weeks "Rumours" has been on the chart. Write a comment explaining how you selected this value.

# %%
# YOUR CODE HERE
print(albums[2][2])
# Select "Rumours" using index 2 (the 3rd album in the list), 
# then select index 2 of that tuple to get the number of weeks on the chart (647).
rumours_weeks = albums[2][2]
print(rumours_weeks)
# Out:
# 647
# 647

# %% [markdown]
# (d) Conan Gray's new album "Wishbone" entered the chart that week for the first time at #3. Add this album data in a tuple to the list `albums`.

# %%
# YOUR CODE HERE
albums.append(("Wishbone", "Conan Gray", 1, True))
print(albums)
# Out:
# [('SOS', 'SZA', 141, True), ('DeBÍ TiRAR MáS FOToS', 'Bad Bunny', 33, False), ('Rumours', 'Fleetwood Mac', 647, False), ('The Dark Side of the Moon', 'Pink Floyd', 741, False), ('Wishbone', 'Conan Gray', 1, True), ('Wishbone', 'Conan Gray', 1, True)]

# %% [markdown]
# ***
# _End of Lab 1_
